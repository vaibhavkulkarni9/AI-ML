# %%
import numpy as np
import pandas as pd

# %%
labels =['w','x','y','z']

# %%
list =[10,20,30,40]

# %%
array =np.array ([10,20,30,40])

# %%
dict={'w':10,'x':20,'y':30,'z':40}

# %%
pd.Series(list,labels)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
pd.Series(data=dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
pd.Series(array)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int32

# %%
pd.Series(array,labels)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int32

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
sports1=pd.Series([1,2,3,4],index=['Cricket','Football','Basketball','Golf'])

# %%
sports1
# Out:
# Cricket       1
# Football      2
# Basketball    3
# Golf          4
# dtype: int64

# %%
sports1[1]
# Out:
# 2

# %%
sports2=pd.Series([2,5,7,1],index=['Cricket','Football','BaseBall','Badminton'])

# %%
sports2
# Out:
# Cricket      2
# Football     5
# BaseBall     7
# Badminton    1
# dtype: int64

# %%
sports1+sports1
# Out:
# Cricket       4
# Football     10
# BaseBall     14
# Badminton     2
# dtype: int64

# %%
from numpy .random import randn

# %%
np.random.seed(1200)

# %%
dataframe=pd.DataFrame(randn(8,8),index='A B C D E F G H'.split(),
                       columns='Score1 Score2 Score3 Score4 Score5 Score6 Score7 Score8'.split())

# %%
dataframe
# Out:
#      Score1    Score2    Score3    Score4    Score5    Score6    Score7  \
# A  0.522022  0.069947  0.869230  0.424554 -0.220960 -0.632086 -0.455699
# B  0.387163 -0.009748 -1.344962 -0.010275  0.704485 -1.958639  0.153709
# C -0.504342  1.349764  0.731516  1.011621 -0.637194 -0.194763  1.103719
# D -1.162580  0.324676 -0.032394  0.351848 -1.702749 -0.089254 -0.822555
# E -0.537568 -1.319745  0.014571  2.606340 -0.531054  1.379970 -0.740361
# F  0.110074 -0.127004 -0.600323 -0.892693  0.462145  0.204553 -1.846770
# G  0.006627  1.230068  0.585755 -1.359024  0.743867 -0.854340 -0.046672
# H  1.685338  1.497130  0.785847  0.291503  1.364972 -1.284961 -0.347377
#
#      Score8
# A -0.681874
# B  1.233067
# C -0.072570
# D -1.831628
# E -1.332955
# F  1.263863
# G -0.725745
# H  0.569770

# %%
dataframe['Score4']
# Out:
# A    0.424554
# B   -0.010275
# C    1.011621
# D    0.351848
# E    2.606340
# F   -0.892693
# G   -1.359024
# H    0.291503
# Name: Score4, dtype: float64

# %%
dataframe[['Score2','Score1','Score5','Score8']]
# Out:
#      Score2    Score1    Score5    Score8
# A  0.069947  0.522022 -0.220960 -0.681874
# B -0.009748  0.387163  0.704485  1.233067
# C  1.349764 -0.504342 -0.637194 -0.072570
# D  0.324676 -1.162580 -1.702749 -1.831628
# E -1.319745 -0.537568 -0.531054 -1.332955
# F -0.127004  0.110074  0.462145  1.263863
# G  1.230068  0.006627  0.743867 -0.725745
# H  1.497130  1.685338  1.364972  0.569770

# %%
dataframe['Score9'] = dataframe['Score3'] + dataframe['Score7']

# %%
dataframe
# Out:
#      Score1    Score2    Score4    Score5    Score6    Score7    Score8  \
# A  0.522022  0.069947  0.424554 -0.220960 -0.632086 -0.455699 -0.681874
# B  0.387163 -0.009748 -0.010275  0.704485 -1.958639  0.153709  1.233067
# C -0.504342  1.349764  1.011621 -0.637194 -0.194763  1.103719 -0.072570
# D -1.162580  0.324676  0.351848 -1.702749 -0.089254 -0.822555 -1.831628
# E -0.537568 -1.319745  2.606340 -0.531054  1.379970 -0.740361 -1.332955
# F  0.110074 -0.127004 -0.892693  0.462145  0.204553 -1.846770  1.263863
# G  0.006627  1.230068 -1.359024  0.743867 -0.854340 -0.046672 -0.725745
# H  1.685338  1.497130  0.291503  1.364972 -1.284961 -0.347377  0.569770
#
#      Score9
# A  0.413531
# B -1.191253
# C  1.835234
# D -0.854948
# E -0.725790
# F -2.447093
# G  0.539083
# H  0.438470

# %%
dataframe.drop('Score3',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-73-6fe79e14488c> in <module>
# ----> 1 dataframe.drop('Score3',axis=1,inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %%
dataframe
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe.drop('A')
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe.iloc[2]
# Out:
# Score1   -0.504342
# Score2    1.349764
# Score5   -0.637194
# Score6   -0.194763
# Score7    1.103719
# Score8   -0.072570
# Score9    1.835234
# Name: C, dtype: float64

# %%
dataframe
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe.iloc[1]
# Out:
# Score1    0.387163
# Score2   -0.009748
# Score5    0.704485
# Score6   -1.958639
# Score7    0.153709
# Score8    1.233067
# Score9   -1.191253
# Name: B, dtype: float64

# %%
dataframe
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe.loc['G','Score5']
# Out:
# 0.7438665364691087

# %%
dataframe >=0.4
# Out:
#    Score1  Score2  Score5  Score6  Score7  Score8  Score9
# A    True   False   False   False   False   False    True
# B   False   False    True   False   False    True   False
# C   False    True   False   False    True   False    True
# D   False   False   False   False   False   False   False
# E   False   False   False    True   False   False   False
# F   False   False    True   False   False    True   False
# G   False    True    True   False   False   False    True
# H    True    True    True   False   False    True    True

# %%
dataframe.loc[['D','F','H'],['Score2','Score5','Score8']]
# Out:
#      Score2    Score5    Score8
# D  0.324676 -1.702749 -1.831628
# F -0.127004  0.462145  1.263863
# H  1.497130  1.364972  0.569770

# %%
dataframe
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe[dataframe>0.5]
# Out:
#      Score1    Score2    Score5   Score6    Score7    Score8    Score9
# A  0.522022       NaN       NaN      NaN       NaN       NaN       NaN
# B       NaN       NaN  0.704485      NaN       NaN  1.233067       NaN
# C       NaN  1.349764       NaN      NaN  1.103719       NaN  1.835234
# D       NaN       NaN       NaN      NaN       NaN       NaN       NaN
# E       NaN       NaN       NaN  1.37997       NaN       NaN       NaN
# F       NaN       NaN       NaN      NaN       NaN  1.263863       NaN
# G       NaN  1.230068  0.743867      NaN       NaN       NaN  0.539083
# H  1.685338  1.497130  1.364972      NaN       NaN  0.569770       NaN

# %%
dataframe[dataframe['Score1']>0.5]
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe[dataframe['Score1']>0.5]['Score2']
# Out:
# A    0.069947
# H    1.497130
# Name: Score2, dtype: float64

# %%
dataframe[dataframe['Score1']>0.5][['Score2','Score8','Score9']]
# Out:
#      Score2    Score8    Score9
# A  0.069947 -0.681874  0.413531
# H  1.497130  0.569770  0.438470

# %%
dataframe
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe[(dataframe['Score1']>0.5) & (dataframe['Score9'] >3)]
# Out:
# Empty DataFrame
# Columns: [Score1, Score2, Score5, Score6, Score7, Score8, Score9]
# Index: []

# %%
dataframe[dataframe['Score1']>0.5][0:2]
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
dataframe.reset_index()
# Out:
#   index    Score1    Score2    Score5    Score6    Score7    Score8    Score9
# 0     A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# 1     B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# 2     C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# 3     D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# 4     E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# 5     F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# 6     G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# 7     H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470

# %%
newindex = 'IND JP US UK FN CAN BUL MX'.split()
dataframe['Countries'] = newindex

# %%
dataframe
# Out:
#      Score1    Score2    Score5    Score6    Score7    Score8    Score9  \
# A  0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874  0.413531
# B  0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067 -1.191253
# C -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570  1.835234
# D -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628 -0.854948
# E -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955 -0.725790
# F  0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863 -2.447093
# G  0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745  0.539083
# H  1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770  0.438470
#
#   Countries
# A       IND
# B        JP
# C        US
# D        UK
# E        FN
# F       CAN
# G       BUL
# H        MX

# %%
dataframe.set_index('Countries')
# Out:
#              Score1    Score2    Score5    Score6    Score7    Score8  \
# Countries
# IND        0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874
# JP         0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067
# US        -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570
# UK        -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628
# FN        -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955
# CAN        0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863
# BUL        0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745
# MX         1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770
#
#              Score9
# Countries
# IND        0.413531
# JP        -1.191253
# US         1.835234
# UK        -0.854948
# FN        -0.725790
# CAN       -2.447093
# BUL        0.539083
# MX         0.438470

# %%
dataframe
# Out:
#              Score1    Score2    Score5    Score6    Score7    Score8  \
# Countries
# IND        0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874
# JP         0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067
# US        -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570
# UK        -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628
# FN        -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955
# CAN        0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863
# BUL        0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745
# MX         1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770
#
#              Score9
# Countries
# IND        0.413531
# JP        -1.191253
# US         1.835234
# UK        -0.854948
# FN        -0.725790
# CAN       -2.447093
# BUL        0.539083
# MX         0.438470

# %%
dataframe.set_index('Countries', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Countries'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-53e0264847e8> in <module>
# ...

# %%
dataframe
# Out:
#              Score1    Score2    Score5    Score6    Score7    Score8  \
# Countries
# IND        0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874
# JP         0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067
# US        -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570
# UK        -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628
# FN        -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955
# CAN        0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863
# BUL        0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745
# MX         1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770
#
#              Score9
# Countries
# IND        0.413531
# JP        -1.191253
# US         1.835234
# UK        -0.854948
# FN        -0.725790
# CAN       -2.447093
# BUL        0.539083
# MX         0.438470

# %%
dataframe
# Out:
#              Score1    Score2    Score5    Score6    Score7    Score8  \
# Countries
# IND        0.522022  0.069947 -0.220960 -0.632086 -0.455699 -0.681874
# JP         0.387163 -0.009748  0.704485 -1.958639  0.153709  1.233067
# US        -0.504342  1.349764 -0.637194 -0.194763  1.103719 -0.072570
# UK        -1.162580  0.324676 -1.702749 -0.089254 -0.822555 -1.831628
# FN        -0.537568 -1.319745 -0.531054  1.379970 -0.740361 -1.332955
# CAN        0.110074 -0.127004  0.462145  0.204553 -1.846770  1.263863
# BUL        0.006627  1.230068  0.743867 -0.854340 -0.046672 -0.725745
# MX         1.685338  1.497130  1.364972 -1.284961 -0.347377  0.569770
#
#              Score9
# Countries
# IND        0.413531
# JP        -1.191253
# US         1.835234
# UK        -0.854948
# FN        -0.725790
# CAN       -2.447093
# BUL        0.539083
# MX         0.438470

# %%
dataframe=pd.DataFrame({'Cricket':[1,2,np.nan,4,5,6,7,8],'BaseBall':[np.nan,5,6,7,8,3,2,4]})

# %%
dataframe
# Out:
#    Cricket  BaseBall
# 0      1.0       NaN
# 1      2.0       5.0
# 2      NaN       6.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe.reset_index()
# Out:
#    index  Cricket  BaseBall
# 0      0      1.0       NaN
# 1      1      2.0       5.0
# 2      2      NaN       6.0
# 3      3      4.0       7.0
# 4      4      5.0       8.0
# 5      5      6.0       3.0
# 6      6      7.0       2.0
# 7      7      8.0       4.0

# %%
dataframe
# Out:
#    Cricket  BaseBall
# 0      1.0       NaN
# 1      2.0       5.0
# 2      NaN       6.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe.dropna()
# Out:
#    Cricket  BaseBall
# 1      2.0       5.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe
# Out:
#    Cricket  BaseBall
# 0      1.0       NaN
# 1      2.0       5.0
# 2      NaN       6.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7]

# %%
dataframe
# Out:
#    Cricket  BaseBall
# 0      1.0       NaN
# 1      2.0       5.0
# 2      NaN       6.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe
# Out:
#    Cricket  BaseBall
# 0      1.0       NaN
# 1      2.0       5.0
# 2      NaN       6.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe.fillna(value=0)
# Out:
#    Cricket  BaseBall
# 0      1.0       0.0
# 1      2.0       5.0
# 2      0.0       6.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe.fillna(value=0)
# Out:
#    Cricket  BaseBall
# 0      1.0       0.0
# 1      2.0       5.0
# 2      0.0       6.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe
# Out:
#    Cricket  BaseBall
# 0      1.0       NaN
# 1      2.0       5.0
# 2      NaN       6.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe['Cricket'].fillna(value=dataframe['Cricket'].mean())
# Out:
# 0    1.000000
# 1    2.000000
# 2    4.714286
# 3    4.000000
# 4    5.000000
# 5    6.000000
# 6    7.000000
# 7    8.000000
# Name: Cricket, dtype: float64

# %%
dataframe['BaseBall'].fillna(value=dataframe['Cricket'].mean())
# Out:
# 0    4.714286
# 1    5.000000
# 2    6.000000
# 3    7.000000
# 4    8.000000
# 5    3.000000
# 6    2.000000
# 7    4.000000
# Name: BaseBall, dtype: float64

# %%
dataframe.fillna(value=dataframe['BaseBall'].mean())
# Out:
#    Cricket  BaseBall
# 0      1.0       5.0
# 1      2.0       5.0
# 2      5.0       6.0
# 3      4.0       7.0
# 4      5.0       8.0
# 5      6.0       3.0
# 6      7.0       2.0
# 7      8.0       4.0

# %%
dataframe['Cricket'].mean()
# Out:
# 4.714285714285714

# %%
dat={'CustID':['1001','1002','1003','1004','1005','1002','1004'], 
     'CustName':['Google','Facebook','GM','Ford','Amazon','LinkedIn','Microsoft'],
     'Profit in Billions':[2005,4005,6007,8002,10012,60023,90432]}

# %%
dat
# Out:
# {'CustID': ['1001', '1002', '1003', '1004', '1005', '1002', '1004'],
#  'CustName': ['Google',
#   'Facebook',
#   'GM',
#   'Ford',
#   'Amazon',
#   'LinkedIn',
#   'Microsoft'],
#  'Profit in Billions': [2005, 4005, 6007, 8002, 10012, 60023, 90432]}

# %%
dataframe=pd.DataFrame(dat)

# %%
dataframe
# Out:
#   CustID   CustName  Profit in Billions
# 0   1001     Google                2005
# 1   1002   Facebook                4005
# 2   1003         GM                6007
# 3   1004       Ford                8002
# 4   1005     Amazon               10012
# 5   1002   LinkedIn               60023
# 6   1004  Microsoft               90432

# %%
grouped_custID = dataframe.groupby('CustID')

# %%
grouped_custID

# %%
grouped_custID.mean()
# Out:
#         Profit in Billions
# CustID
# 1001                  2005
# 1002                 32014
# 1003                  6007
# 1004                 49217
# 1005                 10012

# %%
grouped_custID.std()
# Out:
#         Profit in Billions
# CustID
# 1001                   NaN
# 1002          39610.707669
# 1003                   NaN
# 1004          58286.811973
# 1005                   NaN

# %%
grouped_custID.var()
# Out:
#         Profit in Billions
# CustID
# 1001                   NaN
# 1002          1.569008e+09
# 1003                   NaN
# 1004          3.397352e+09
# 1005                   NaN

# %%
dataframe
# Out:
#   CustID   CustName  Profit in Billions
# 0   1001     Google                2005
# 1   1002   Facebook                4005
# 2   1003         GM                6007
# 3   1004       Ford                8002
# 4   1005     Amazon               10012
# 5   1002   LinkedIn               60023
# 6   1004  Microsoft               90432

# %%
grouped_custID.max()
# Out:
#          CustName  Profit in Billions
# CustID
# 1001       Google                2005
# 1002     LinkedIn               60023
# 1003           GM                6007
# 1004    Microsoft               90432
# 1005       Amazon               10012

# %%
grouped_custID.min()
# Out:
#         CustName  Profit in Billions
# CustID
# 1001      Google                2005
# 1002    Facebook                4005
# 1003          GM                6007
# 1004        Ford                8002
# 1005      Amazon               10012

# %%
grouped_custID.count()
# Out:
#         CustName  Profit in Billions
# CustID
# 1001           1                   1
# 1002           2                   2
# 1003           1                   1
# 1004           2                   2
# 1005           1                   1

# %%
grouped_custID.describe().transpose()['1004']
# Out:
# Profit in Billions  count        2.000000
#                     mean     49217.000000
#                     std      58286.811973
#                     min       8002.000000
#                     25%      28609.500000
#                     50%      49217.000000
#                     75%      69824.500000
#                     max      90432.000000
# Name: 1004, dtype: float64

# %%
dataframe
# Out:
#   CustID   CustName  Profit in Billions
# 0   1001     Google                2005
# 1   1002   Facebook                4005
# 2   1003         GM                6007
# 3   1004       Ford                8002
# 4   1005     Amazon               10012
# 5   1002   LinkedIn               60023
# 6   1004  Microsoft               90432

# %%
grouped_custID

# %%
grouped_custID.describe()
# Out:
#        Profit in Billions                                                    \
#                     count     mean           std      min      25%      50%
# CustID
# 1001                  1.0   2005.0           NaN   2005.0   2005.0   2005.0
# 1002                  2.0  32014.0  39610.707669   4005.0  18009.5  32014.0
# 1003                  1.0   6007.0           NaN   6007.0   6007.0   6007.0
# 1004                  2.0  49217.0  58286.811973   8002.0  28609.5  49217.0
# 1005                  1.0  10012.0           NaN  10012.0  10012.0  10012.0
#
#
#             75%      max
# CustID
# 1001     2005.0   2005.0
# 1002    46018.5  60023.0
# 1003     6007.0   6007.0
# 1004    69824.5  90432.0
# 1005    10012.0  10012.0

# %%
dataf1=pd.DataFrame({'CustID':['1001','1002','1003','1004','1005','1002','1004'], 
     'CustName':['Google','Facebook','GM','Ford','Amazon','LinkedIn','Microsoft'],
     'Profit in Billions':[2005,4005,6007,8002,10012,60023,90432],
      'Prime':[11,22,33,44,55,66,77]},index=[1,2,3,4,5,6,7]),

dataf2=pd.DataFrame({'CustID':['1001','1002','1003','1004','1005','1002','1004'], 
     'CustName':['Google','Facebook','GM','Ford','Amazon','LinkedIn','Microsoft'],
     'Profit in Billions':[2005,4005,6007,8002,10012,60023,90432],
     'Scale':[34,45,56,67,78,89,102]},index=[11,12,13,14,15,16,17])

# %%
pd.concat([dataf1+dataf2],axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-206-6545611fefd6> in <module>
# ----> 1 pd.concat([dataf1+dataf2],axis=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in f(self, other, axis, level, fill_value)
#    2016     def f(self, other, axis=default_axis, level=None, fill_value=None):
#    2017
# -> 2018         other = _align_method_FRAME(self, other, axis)
#    2019
#    2020         if isinstance(other, ABCDataFrame):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in _align_method_FRAME(left, right, axis)
#    1983           not isinstance(right, (ABCSeries, ABCDataFrame))):
#    1984         # GH17901
# -> 1985         right = to_series(right)
#    1986
#    1987     return right
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in to_series(right)
# ...

# %%
df1=pd.DataFrame({'Q1':['1001','1002','1003'], 
     'Q2':['C1','V1','B1']},index=['P1','P2','P3'])

df2=pd.DataFrame({'Q3':['1002','3002','1001'], 
     'Q4':['D1','F1','S1']},index=['P1','P2','P4'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f6ad8f10094a> in <module>
# ----> 1 df1=pd.DataFrame({'Q1':['1001','1002','1003'],
#       2      'Q2':['C1','V1','B1']},index=['P1','P2','P3'])
#       3
#       4 df2=pd.DataFrame({'Q3':['1002','3002','1001'],
#       5      'Q4':['D1','F1','S1']},index=['P1','P2','P4'])
#
# NameError: name 'pd' is not defined

# %%
df1.join(df2)
# Out:
#       Q1  Q2    Q3   Q4
# P1  1001  C1  3001   D1
# P2  1002  V1  3002   F1
# P3  1003  B1   NaN  NaN

# %%
df1.join(df2,how='right')
# Out:
#       Q1   Q2    Q3  Q4
# P1  1001   C1  3001  D1
# P2  1002   V1  3002  F1
# P4   NaN  NaN  3003  S1

# %%
dafa1=pd.DataFrame({'CustID':['101','102','103','104'],'Sales':[1545,6572,8712,9815],
                    'Priority':['CAT0','CAT1','CAT2','CAT3'],'Prime':['yes','no','no','yes'],
                    'Payback':['10','20','30','40']},
                  index=[0,1,2,3])

dafa2=pd.DataFrame({'CustID':['101','103','106','102'],'Sales':[1545,6572,8712,9815],
                    'Priority':['CAT1','CAT7','CAT2','CAT3'],'Prime':['yes','no','no','yes']},
                  index=[4,5,6,7])
pd.concat([dafa1,dafa2],axis=1)
# Out:
#   CustID   Sales Priority Prime Payback CustID   Sales Priority Prime
# 0    101  1545.0     CAT0   yes      10    NaN     NaN      NaN   NaN
# 1    102  6572.0     CAT1    no      20    NaN     NaN      NaN   NaN
# 2    103  8712.0     CAT2    no      30    NaN     NaN      NaN   NaN
# 3    104  9815.0     CAT3   yes      40    NaN     NaN      NaN   NaN
# 4    NaN     NaN      NaN   NaN     NaN    101  1545.0     CAT1   yes
# 5    NaN     NaN      NaN   NaN     NaN    103  6572.0     CAT7    no
# 6    NaN     NaN      NaN   NaN     NaN    106  8712.0     CAT2    no
# 7    NaN     NaN      NaN   NaN     NaN    102  9815.0     CAT3   yes

# %%
pd.merge(dafa1,dafa2,how='outer',on='CustID')
# Out:
#   CustID  Sales_x Priority_x Prime_x Payback  Sales_y Priority_y Prime_y
# 0    101   1545.0       CAT0     yes      10   1545.0       CAT1     yes
# 1    102   6572.0       CAT1      no      20   9815.0       CAT3     yes
# 2    103   8712.0       CAT2      no      30   6572.0       CAT7      no
# 3    104   9815.0       CAT3     yes      40      NaN        NaN     NaN
# 4    106      NaN        NaN     NaN     NaN   8712.0       CAT2      no

# %%
df1=pd.DataFrame({'Q1':['1001','1002','1003'], 
     'Q2':['C1','V1','B1']},index=['I1','I2','I3'])

df2=pd.DataFrame({'Q3':['1002','3002','1001'], 
     'Q4':['D1','F1','S1']},index=['I1','I2','I4'])

# %%
df1.join(df2)
# Out:
#       Q1  Q2    Q3   Q4
# I1  1001  C1  1002   D1
# I2  1002  V1  3002   F1
# I3  1003  B1   NaN  NaN

# %%
df1.join(df2,how='outer')
# Out:
#       Q1   Q2    Q3   Q4
# I1  1001   C1  1002   D1
# I2  1002   V1  3002   F1
# I3  1003   B1   NaN  NaN
# I4   NaN  NaN  1001   S1

# %%
dataframe=pd.DataFrame({'CustID':[1,2,3,4],'CustName':[np.nan,'Webs','Mongo',np.nan],'SalesCode':['S1',np.nan,'S1','S4']})

# %%
dataframe
# Out:
#    CustID CustName SalesCode
# 0       1      NaN        S1
# 1       2     Webs       NaN
# 2       3    Mongo        S1
# 3       4      NaN        S4

# %%
dataframe.head(2)
# Out:
#    CustID CustName SalesCode
# 0       1      Ron        S1
# 1       2     Webs        S2

# %%
dataframe['SalesCode'].value_counts()
# Out:
# S1    2
# S2    1
# S4    1
# Name: SalesCode, dtype: int64

# %%
newdataframe=dataframe[(dataframe['CustID']!=3) & (dataframe['SalesCode']=='S1')]

# %%
newdataframe
# Out:
#    CustID CustName SalesCode
# 0       1      Ron        S1

# %%
def profit(a):
    return a*600000

# %%
dataframe['CustID'].apply(profit)
# Out:
# 0     600000
# 1    1200000
# 2    1800000
# 3    2400000
# Name: CustID, dtype: int64

# %%
dataframe['CustID'].sum()
# Out:
# 10

# %%
dataframe.columns
# Out:
# Index(['CustID', 'CustName', 'SalesCode'], dtype='object')

# %%
dataframe.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
dataframe.sort_values(by='CustName',axis=0)
# Out:
#    CustID CustName SalesCode
# 3       4  Fortran        S4
# 2       3    Mongo        S1
# 0       1      Ron        S1
# 1       2     Webs        S2

# %%
dataframe.isnull()
# Out:
#    CustID  CustName  SalesCode
# 0   False     False      False
# 1   False     False      False
# 2   False     False      False
# 3   False     False      False

# %%
dataframe
# Out:
#    CustID CustName SalesCode
# 0       1      NaN        S1
# 1       2     Webs       NaN
# 2       3    Mongo        S1
# 3       4      NaN        S4

# %%
dataframe.dropna()
# Out:
#    CustID CustName SalesCode
# 2       3    Mongo        S1

# %%
dataframe
# Out:
#    CustID CustName SalesCode
# 0       1      NaN        S1
# 1       2     Webs       NaN
# 2       3    Mongo        S1
# 3       4      NaN        S4

# %%
dataframe.fillna('Not Available')
# Out:
#    CustID       CustName      SalesCode
# 0       1  Not Available             S1
# 1       2           Webs  Not Available
# 2       3          Mongo             S1
# 3       4  Not Available             S4

# %%
dataframe=pd.read_csv('pandas-train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-82-13adb4658457> in <module>
# ----> 1 dataframe=pd.read_csv('pandas-train.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
# ...

# %%
pd.read_excel('Environment_Details_Media.xlsx',sheet_name='Charter Media DEV')
# Out:
#                    Unnamed: 0                                 Unnamed: 1  \
# 0                         NaN                                        NaN
# 1   Charter Media DEV (port?)                                        NaN
# 2                MDM Location      /charter/apps/rdm/Teradata/MDM_Reach/
# 3            MDM Log location  /charter/apps/rdm/Teradata/MDM_Reach/log/
# 4             Tomcat Location      /charter/apps/rdm/tomcat-8_MDM_Reach/
# 5         Tomcat Log Location  /charter/apps/rdm/tomcat-8_MDM_Reach/log/
# 6         Collapsed/Colocated                                  Collapsed
# 7            Eclipse Location                                        NaN
# 8                   Database                                      CHTRT1
# 9            Database User ID                                  MDM_CHRMD
# 10          Database Password                               Charter@123#
# 11           Unix Box Address                                sc58lrdmd01
# ...

# %%
dataframe2=pd.read_excel('Environment_Details_Media.xlsx',sheet_name='Charter Media DEV')

# %%
dataframe2
# Out:
#                    Unnamed: 0                                 Unnamed: 1  \
# 0                         NaN                                        NaN
# 1   Charter Media DEV (port?)                                        NaN
# 2                MDM Location      /charter/apps/rdm/Teradata/MDM_Reach/
# 3            MDM Log location  /charter/apps/rdm/Teradata/MDM_Reach/log/
# 4             Tomcat Location      /charter/apps/rdm/tomcat-8_MDM_Reach/
# 5         Tomcat Log Location  /charter/apps/rdm/tomcat-8_MDM_Reach/log/
# 6         Collapsed/Colocated                                  Collapsed
# 7            Eclipse Location                                        NaN
# 8                   Database                                      CHTRT1
# 9            Database User ID                                  MDM_CHRMD
# 10          Database Password                               Charter@123#
# 11           Unix Box Address                                sc58lrdmd01
# ...

# %%
dataframe2.to_excel('Charter.xlsx',sheet_name='Sheet1_Charter')
