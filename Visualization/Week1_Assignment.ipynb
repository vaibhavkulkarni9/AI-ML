# %%
import numpy as np

# %%
l1 = ['learning', 'is', 'fun',True]

# %%
np.array(l1)
# Out:
# array(['learning', 'is', 'fun', 'True'], dtype='<U8')

# %%
l2 = list(("learning", "is", "life"))

# %%
np.array(l2)
# Out:
# array(['learning', 'is', 'life'], dtype='<U8')

# %%
l1.append(10)

# %%
np.array(l1)
# Out:
# array(['learning', 'is', 'fun', 'True', '10'], dtype='<U8')

# %%
l1.remove('is')

# %%
np.array(l1)
# Out:
# array(['learning', 'fun', 'True', '10'], dtype='<U8')

# %%
l1+l2
# Out:
# ['learning', 'fun', True, 10, 'learning', 'is', 'life']

# %%
l3=[3,4,6,8,9]

# %%
count(l3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-013621db9d78> in <module>
# ----> 1 count(l3)
#
# NameError: name 'count' is not defined

# %%
def sum_3 (a,b,c):
    d = a+b+c
    return d

# %%
sum_3(1.541,22.43,34.32)
# Out:
# 58.291

# %%
f = lambda x,y,z : x+y+z

# %%
f(1.541,22.43,34.32)
# Out:
# 58.291

# %%
import numpy as np
import pandas as pd

# %%
series2 = pd.Series(data = [1,2,3], index = ['key1', 'key2', 'key3'])

# %%
series2
# Out:
# key1    1
# key2    2
# key3    3
# dtype: int64

# %%
d1 = {'a': [1,2,3], 'b': [3,4,5], 'c':[6,7,8] }
df1 = pd.DataFrame(d1)
df1
# Out:
#    a  b  c
# 0  1  3  6
# 1  2  4  7
# 2  3  5  8

# %%
df1
# Out:
#    a  b  c
# 0  1  3  6
# 1  2  4  7
# 2  3  5  8

# %%
df1[2,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-f394d7535b5b> in <module>
# ----> 1 df1[2,:]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# ...

# %%
dict = {'w':10,'x':20,'y':30,'z':40}

# %%
pd.Series(dict)
# Out:
# w    10
# x    20
# y    30
# z    40
# dtype: int64

# %%
d1 = {'a': [1,2,3], 'b': [3,4,5], 'c':[6,7,8] }

# %%
d1
# Out:
# {'a': [1, 2, 3], 'b': [3, 4, 5], 'c': [6, 7, 8]}

# %%
df1=pd.DataFrame(d1)

# %%
df1
# Out:
#    a  b  c
# 0  1  3  6
# 1  2  4  7
# 2  3  5  8

# %%
df1.iloc[1]
# Out:
# a    2
# b    4
# c    7
# Name: 1, dtype: int64

# %%
df1.head(2)
# Out:
#    a  b  c
# 0  1  3  6
# 1  2  4  7

# %%
df1.iloc[1,2]
# Out:
# 7

# %%
mtcars = pd.read_csv('mtcars.csv')
mtcars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars
# Out:
#                                     name   mpg  cyl   disp   hp  drat     wt  \
# name
# Mazda RX4                      Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag              Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                    Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive            Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout      Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# Valiant                          Valiant  18.1    6  225.0  105  2.76  3.460
# Duster 360                    Duster 360  14.3    8  360.0  245  3.21  3.570
# Merc 240D                      Merc 240D  24.4    4  146.7   62  3.69  3.190
# Merc 230                        Merc 230  22.8    4  140.8   95  3.92  3.150
# Merc 280                        Merc 280  19.2    6  167.6  123  3.92  3.440
# Merc 280C                      Merc 280C  17.8    6  167.6  123  3.92  3.440
# ...

# %%
mtcars.count()
# Out:
# name    32
# mpg     32
# cyl     32
# disp    32
# hp      32
# drat    32
# wt      32
# qsec    32
# vs      32
# am      32
# gear    32
# carb    32
# dtype: int64

# %%
mtcars.reshape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-3060a7d14051> in <module>
# ----> 1 mtcars.reshape()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
df = mtcars

# %%
df.count()
# Out:
# name    32
# mpg     32
# cyl     32
# disp    32
# hp      32
# drat    32
# wt      32
# qsec    32
# vs      32
# am      32
# gear    32
# carb    32
# dtype: int64

# %%
mtcars.reset_index;
mtcars
# Out:
#                                     name   mpg  cyl   disp   hp  drat     wt  \
# name
# Mazda RX4                      Mazda RX4  21.0    6  160.0  110  3.90  2.620
# Mazda RX4 Wag              Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875
# Datsun 710                    Datsun 710  22.8    4  108.0   93  3.85  2.320
# Hornet 4 Drive            Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215
# Hornet Sportabout      Hornet Sportabout  18.7    8  360.0  175  3.15  3.440
# Valiant                          Valiant  18.1    6  225.0  105  2.76  3.460
# Duster 360                    Duster 360  14.3    8  360.0  245  3.21  3.570
# Merc 240D                      Merc 240D  24.4    4  146.7   62  3.69  3.190
# Merc 230                        Merc 230  22.8    4  140.8   95  3.92  3.150
# Merc 280                        Merc 280  19.2    6  167.6  123  3.92  3.440
# Merc 280C                      Merc 280C  17.8    6  167.6  123  3.92  3.440
# ...

# %%
mtcars
mtcars.loc[[0,1,2,3,4,5],['name','mpg','cyl']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-002ab2313060> in <module>
#       1 mtcars
# ----> 2 mtcars.loc[[0,1,2,3,4,5],['name','mpg','cyl']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     875         # ugly hack for GH #836
#     876         if self._multi_take_opportunity(tup):
# --> 877             return self._multi_take(tup)
#     878
#     879         # no shortcut needed
#
# ...

# %%
mtcars.loc[[0,1,2,3,4,5],['mpg','cyl']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-3cd7b27615d5> in <module>
# ----> 1 mtcars.loc[[0,1,2,3,4,5],['mpg','cyl']]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1492             except (KeyError, IndexError, AttributeError):
#    1493                 pass
# -> 1494             return self._getitem_tuple(key)
#    1495         else:
#    1496             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     875         # ugly hack for GH #836
#     876         if self._multi_take_opportunity(tup):
# --> 877             return self._multi_take(tup)
#     878
#     879         # no shortcut needed
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
# ...

# %%
mtcars.reset_index()
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars.drop('name',axis=1,inplace=True)

# %%
mtcars
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# name
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
mtcars.reset_index(inplace=True)

# %%
mtcars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars
# Out:
#                    name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
mtcars.loc[[0,1,2,3,4,5],['mpg','cyl']]
# Out:
#     mpg  cyl
# 0  21.0    6
# 1  21.0    6
# 2  22.8    4
# 3  21.4    6
# 4  18.7    8
# 5  18.1    6

# %%
mtcars.loc[[0,1,2,3,4,5],['mpg','cyl']]
# Out:
#     mpg  cyl
# 0  21.0    6
# 1  21.0    6
# 2  22.8    4
# 3  21.4    6
# 4  18.7    8
# 5  18.1    6

# %%
mtcars.loc[[1,5]
# Out:
#   File "<ipython-input-155-8499cf32c9f8>", line 1
#     mtcars.loc[[1,5]
#                     ^
# SyntaxError: unexpected EOF while parsing

# %%
mtcars
