# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
mydataframe = pd.read_csv('CardioGoodFitness.csv')

# %%
mydataframe.head ()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
mydataframe.describe (include='all')
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
mydataframe.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
# Product          180 non-null object
# Age              180 non-null int64
# Gender           180 non-null object
# Education        180 non-null int64
# MaritalStatus    180 non-null object
# Usage            180 non-null int64
# Fitness          180 non-null int64
# Income           180 non-null int64
# Miles            180 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 12.7+ KB

# %%
mydataframe.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B5CB30AC18>,
# ...
#       dtype=object)

# %%
sns.boxplot(x="Gender", y="Age", data=mydataframe)

# %%
sns.boxplot(x="Age", y="Gender", data=mydataframe)

# %%
pd.crosstab(mydataframe['Product'],mydataframe ['Gender'])
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
pd.crosstab(mydataframe['Product'],mydataframe ['MaritalStatus'])
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
pd.crosstab(mydataframe['Product'],mydataframe ['Income'])
# Out:
# Income   29562   30699   31836   32973   34110   35247   36384   37521   \
# Product
# TM195         1       1       1       3       2       5       3       2
# TM498         0       0       1       2       3       0       1       0
# TM798         0       0       0       0       0       0       0       0
#
# Income   38658   39795   ...  85906   88396   89641   90886   92131   95508   \
# Product                  ...
# TM195         3       2  ...       0       0       0       0       0       0
# TM498         2       0  ...       0       0       0       0       0       0
# TM798         0       0  ...       1       2       2       3       3       1
#
# Income   95866   99601   103336  104581
# Product
# TM195         0       0       0       0
# TM498         0       0       0       0
# TM798         1       1       1       2
#
# [3 rows x 62 columns]

# %%
pd.crosstab(mydataframe['Product'],mydataframe ['Education'])
# Out:
# Education  12  13  14  15  16  18  20  21
# Product
# TM195       2   3  30   4  39   2   0   0
# TM498       1   2  23   1  31   2   0   0
# TM798       0   0   2   0  15  19   1   3

# %%
sns.countplot(x="Product",data=mydataframe , hue="Gender")

# %%
pd.pivot_table(mydataframe,'Income',index=['Product','Gender'], columns=['MaritalStatus'])
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# TM195   Female  46153.777778  45742.384615
#         Male    50028.000000  43265.842105
# TM498   Female  49724.800000  48920.357143
#         Male    49378.285714  47071.800000
# TM798   Female  84972.250000  58516.000000
#         Male    81431.368421  68216.428571

# %%
pd.pivot_table(mydataframe,'Miles',index=['Product','Gender'], columns=['MaritalStatus'])
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# TM195   Female   74.925926   78.846154
#         Male     80.190476   99.526316
# TM498   Female   94.000000   80.214286
#         Male     87.238095   91.100000
# TM798   Female  215.000000  133.333333
#         Male    176.315789  147.571429

# %%
sns.pairplot(mydataframe)

# %%
mydataframe['Age'].std()
# Out:
# 6.943498135399795

# %%
mydataframe['Age'].mean()
# Out:
# 28.788888888888888

# %%
mydataframe.hist(by ='Gender',column='Age',figsize=(8,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B5D45EE9B0>,
# ...
#       dtype=object)

# %%
sns.distplot(mydataframe['Age'])

# %%
mydataframe.hist(by ='Gender',column='Income',figsize=(8,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B5D4693908>,
# ...
#       dtype=object)

# %%
mydataframe.hist(by ='Gender',column='Miles',figsize=(8,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B5D45EED68>,
# ...
#       dtype=object)

# %%
mydataframe.hist(by ='Product',column='Age',figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B5D58E4828>,
# ...
#       dtype=object)

# %%
mydataframe.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(mydataframe.corr(),annot=True)

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()

# %%
y=mydataframe['Miles']

# %%
x=mydataframe[['Usage', 'Fitness']]

# %%
regr.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
regr.coef_, regr.intercept_
# Out:
# (array([20.21486334, 27.20649954]), -56.74288178464859)

# %%
#Miles = -22.22+ 36.294*Usage  Single Linear Regression 
#Miles = -56.743 + 20.215*Usage + 27.20*Fitness   Multiple Linear Regression
